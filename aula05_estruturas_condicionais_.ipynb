# %% [markdown]
# <a href="https://colab.research.google.com/github/SottoMayor/Python-BlueEdTech/blob/main/aula05_estruturas_condicionais_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Estruturas de controle condicionais**
#
# > São estruturas para controlar o fluxo do programa
#
# Vamos utilizar os famosos SE e SENÃO.
#
# Em Python a estrutura é bem simples, comparado a outras linguagens, mas antes considere esse fluxograma:
#
# ![untitled.png](data:image/png;base64,...)
#
# **Vamos transcrever ele em Python**

# %%
# SE em Python é if
# SENÃO em Python é else

n1 = float(input('Digite a primeira nota: '))
n2 = float(input('Digite a segunda nota: '))
media = (n1 + n2) / 2

if media >= 6: #Retornar True ou False
  print(f'Aluno aprovado com a média: {media}')
else:
  print(f'Aluno reprovado com a média: {media}')

print('Fim do programa!')
# Out:
# Digite a primeira nota: 2
# Digite a segunda nota: 3
# Aluno reprovado com a média: 2.5
# Fim do programa!

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## Exercício 01
#
# Faça um programa que pergunte ao usuário um número e valide se o numero é par ou impar:
#
# * Crie uma variável para receber o valor, com conversão para int
# * Para um número ser par, a divisão dele por 2 tem que dar resto 0

# %%
# Resposta

numero = int(input('Digite o numero: '))

if numero % 2 == 0:
  print('Numero par')
else:
  print('Numero impar')
# Out:
# Digite o numero: 90
# Numero par

# %% [markdown]
# ## Exercício 02
#
# > Parte 1
#
# Faça um script que peça um valor e mostre na tela se o valor é positivo ou negativo.
#
# > Parte 2
#
# Agora implemente a funcionalidade de não aceitar o número 0, no input.

# %%
# Resposta Parte 1

valor = int(input('Valor: '))

if valor > 0:
  print('Valor positivo')
else:
  print('Valor negativo')

# %%
# Resposta Parte 2

valor = int(input('Digite o valor: '))

if valor == 0:
  print('Número inválido!')
else:
  if valor > 0:
    print('Numero positivo')
  else:
    print('Numero negativo')
    
print('Programa finalizado!')
# Out:
# Digite o valor: -456
# Numero negativo
# Programa finalizado!

# %% [markdown]
# # **IF aninhado**
#
# Nesse último exercício a gente precisou utilizar dois if e else para resolver nosso problema, isso se chama If aninhado, vamos continuar treinando esse tipo de if com os exercícios abaixo:

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## Exercício 03
#
# Faça um programa que peça dois números, imprima o maior deles ou imprima "Numeros iguais" se os números forem iguais.

# %%
num1 = int(input('Digite o primeiro numero: '))
num2 = int(input('Digite o segundo numero: '))

if num1 > num2:
  print(f'O numero {num1} é o maior')
else:
  if num1 == num2:
    print("Os numeros são iguais!")
  else:
    print(f'O numero {num2} é o maior')
# Out:
# Digite o primeiro numero: 36
# Digite o segundo numero: 23
# O numero 36 é o maior

# %% [markdown]
# ## Exercício 04
#
# Crie um programa que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F - Feminino, M - Masculino, caso escreva outra letra: Sexo Inválido.

# %%
resposta = input('Digite M ou F: ').upper()

if resposta == 'M':
  print('Masculino')
else:
  if resposta == 'F':
    print('Feminino')
  else:
    print('Você não digitou as letras correta!')
# Out:
# Digite M ou F: f
# Feminino

# %% [markdown]
# # **ELIF**
#
# > O If serve para verificar uma condição e o elif serve para verificar outra condição caso a condição do If seja falsa. No código não há muita diferença, o elif vai garantir que aquela condição seja verificada caso o If seja falso, diferente dos dois If que são 'fluxos' independentes.
#
# Vamos refazer o exemplo da média adicionando a condição de "Aluno em recuperação"

# %%
n1 = float(input('Digite a primeira nota: '))
n2 = float(input('Digite a segunda nota: '))
media = (n1 + n2) / 2

if media >= 6:
  print(f'Aluno aprovado com a média {media}')
elif media >= 4 and media < 6:
  print(f'Aluno está de recuperação com a média {media}')
else:
  print(f'Aluno reprovado com a média {media}')
# Out:
# Digite a primeira nota: 4
# Digite a segunda nota: 5
# Aluno está de recuperação com a média 4.5

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## Exercício 05
#
# Crie um programa em Python que peça a nota do aluno, que deve ser um float entre 0.00 e 10.0
#
# * Se a nota for menor que 6.0, deve exibir a nota F.
#
# * Se a nota for de 6.0 até 7.0, deve exibir a nota D.
#
# * Se a nota for entre 7.0 e 8.0, deve exibir a nota C.
#
# * Se a nota for entre 8.0 e 9.0, deve exibir a nota B.
#
# * Por fim, se for entre 9.0 e 10.0, deve exibir um belo de um A.

# %%
nota = float(input('Qual a nota [0.0 - 10.00]: '))

if nota >= 0 and nota <= 10:
  if nota < 6:
    print('Nota F')
  elif nota < 7:
    print('Nota D')
  elif nota < 8:
    print('Nota C')
  elif nota < 9:
    print('Nota B')
  else:
    print('Nota A')
else:
  print('Nota inválida!')
# Out:
# Qual a nota [0.0 - 10.00]: 9
# Nota A

# %% [markdown]
# # *Projetos*

# %% [markdown]
# ## **PROJETO 01**
#
# *   Escreva um programa que receba uma string digitada pelo usuário;
# *   Caso a string seja "medieval", exiba no console "espada";
# *   Caso contrário, se a string for "futurista", exiba no console "sabre de luz";
# *   Caso contrário, exiba no console "Tente novamente"

# %%
# Resposta:
string = input('Digite se é medieval ou futurista: ').lower()

if(string == 'medieval'):
  print('espada')
elif(string == 'futurista'):
  print('sabre de luz')
else:
  print('Tente novamente')
# Out:
# Digite se é medieval ou futurista: feudal
# Tente novamente

# %% [markdown]
# ## **PROJETO 02**
#
# * Escreva um programa que receba um ataque de espada ou sabre digitada pelo usuário;
#
# * Caso o ataque seja "espada", exiba no console "VOCÊ AINDA NÃO MATOU O CHEFÃO";
#
# * Caso contrário, se o ataque for "sabre", exiba no console "VOCÊ DERROTOU O CHEFÃO COM O SABRE DE LUZ";
#
# * Caso contrário, exiba no console "ATAQUE NOVAMENTE"

# %%
# Resposta:
ataque = input('Seu ataque é de espada ou sabre? ').lower()

if( ataque == 'espada' ):
    print('VOCÊ AINDA NÃO MATOU O CHEFÃO')
elif( ataque == 'sabre' ):
    print('VOCÊ DERROTOU O CHEFÃO COM O SABRE DE LUZ')
else:
  print("ATAQUE NOVAMENTE")
# Out:
# Seu ataque é de espada ou sabre? flecha
# ATAQUE NOVAMENTE

# %% [markdown]
# ## **PROJETO 03 - DESAFIO**
#
# As empresas @.com resolveram dar um aumento de salário aos seus colaboradores e lhe contrataram para desenvolver o programa que calculará os reajustes.
#
# Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:
# * salários até R$ 280,00 (incluindo) : aumento de 20%
#
# * salários entre R\$ 280,00 e R$ 700,00 : aumento de 15%
#
# * salários entre R\$ 700,00 e R$ 1500,00 : aumento de 10%
#
# * salários de R$ 1500,00 em diante : aumento de 5%
#
# Após o aumento ser realizado, informe na tela:
# * o salário antes do reajuste;
#
# * o percentual de aumento aplicado;
#
# * o valor do aumento;
#
# * o novo salário, após o aumento."

# %%
# Resposta:

salario = float(input('Digite o salario do colaborador: '))

if(0 <= salario <= 280):
  perc_aumento = 0.2
  valor_aumento = salario * perc_aumento
  salario_ajustado = salario + valor_aumento
elif(280 < salario <= 700):
  perc_aumento = 0.15
  valor_aumento = salario * perc_aumento
  salario_ajustado = salario + valor_aumento
elif(700 < salario <= 1500):
  perc_aumento = 0.10
  valor_aumento = salario * perc_aumento
  salario_ajustado = salario + valor_aumento
elif(salario > 1500):
  perc_aumento = 0.05
  valor_aumento = salario * perc_aumento
  salario_ajustado = salario + valor_aumento


print(f'O salário do colaborador era de R${salario}')
print(f'O percentual de aumento aplicado foi de {perc_aumento * 100}%')
print(f'O valor do aumento foi de R${valor_aumento}')
print(f'O salário reajustado é de R${salario_ajustado}')
# Out:
# Digite o salario do colaborador: 150
# O salário do colaborador era de R$150.0
# O percentual de aumento aplicado foi de 20.0%
# O valor do aumento foi de R$30.0
# O salário reajustado é de R$180.0

# %% [markdown]
# ## **PROJETO 04 - DESAFIO**
#
# Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário a valor do saque e depois informar quantas notas de cada valor serão fornecidas. As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais. O valor mínimo é de 10 reais e o máximo de 600 reais. O programa não deve se preocupar com a quantidade de notas existentes na máquina.
#
# * Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;
#
# * Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece três notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1.

# %%
# Resposta:
# Resposta:

valor = int(
    input('Digite quantos reais você quer sacar, entre 10 e 600 reais: '))

if(not(10 <= valor <= 600)):
  
  print('Entrada inválida!')

else:

  cem = cinquenta = dez = cinco = um = 0

  valor_centena = valor//100 * 100
  valor_dezena = (valor % 100) // 10 * 10
  valor_unidade = valor % 10

  #parte das centenas
  if(valor_centena >= 100):
    quantidade = valor_centena // 100
    cem = quantidade

  #parte das dezenas
  if(50 <= valor_dezena < 100 ):
    quantidade = valor_dezena // 50
    cinquenta = quantidade
    valor_dezena -= quantidade * 50
  if( 10 <= valor_dezena < 50 ):
    quantidade = valor_dezena // 10
    dez = quantidade
    valor_dezena -= quantidade * 10

  #parte das unidades
  if(5 <= valor_unidade < 10):
    quantidade = valor_unidade // 5
    cinco = quantidade
    valor_unidade -= quantidade * 5
  if(1 <= valor_unidade < 5 ):
    quantidade = valor_unidade
    um = quantidade
    valor_unidade -= quantidade 

  print(
      f'Você terá {cem} notas de R$100, {cinquenta} notas de R$50, {dez} notas ' +
      f'de R$10, {cinco} notas de R$5, {um} notas de R$1'
      )
# Out:
# Digite quantos reais você quer sacar, entre 10 e 600 reais: 650
# Entrada inválida!
